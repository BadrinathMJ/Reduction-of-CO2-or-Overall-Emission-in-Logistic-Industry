# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
import os
co2 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/CO2_Emissions-master/Feature Engineering CO2 Emission Final 1.xlsx')

# %%
co2.head()
# Out:
#    Sr.No.   Year   Jet Fuel_avi_BTU  Gasoline_avi_BTU  LDV_SWB_road_BTU  \
# 0     1.0  1960.0        263.790000           29.0884       4952.283840
# 1     2.0  1965.0        525.015000           35.0984       5980.980778
# 2     3.0  1970.0       1060.695000           66.2302       8164.903979
# 3     4.0  1975.0       1020.330000           49.5224       8931.556064
# 4     5.0  1980.0       1150.096472           62.5040       8442.341323
#
#    LDV_LWB_road_BTU  Combination_Truck_road_BTU  Bus_Road_BTU  Railways_BTU  \
# 0               NaN                         NaN     99.476522    475.750403
# 1               NaN                  800.864188    105.250250    493.472552
# 2       1481.134324                  883.853950     98.660622    487.015645
# 3       2295.138398                 1103.921827    126.666330    502.402317
# 4       2862.349250                 1568.168922    122.489519    536.335424
#
#     Water_BTU  ...  Light_vehicle_Age  \
# 0  108.118847  ...                NaN
# 1   89.572412  ...                NaN
# 2  112.515039  ...                NaN
# 3  150.844338  ...                NaN
# 4  203.049118  ...                NaN
#
#    Demand_petroleum_transportation)mil_lit  Average_MC/15000_miles(dollars)  \
# 0                            230005.240618                              NaN
# 1                            269470.995991                              NaN
# 2                            339177.522046                              NaN
# 3                            389881.923382                           2154.0
# 4                            396853.724860                           3176.0
#
#    CO2_emission_million_metric_tons  CO_emission_million_shots_tons  \
# 0                               NaN                             NaN
# 1                               NaN                             NaN
# 2                               NaN                         204.042
# 3                          1290.801                         188.398
# 4                          1397.368                         185.408
#
#    NOx_emission_million_shots_tons  particulate  \
# 0                              NaN          NaN
# 1                              NaN          NaN
# 2                           26.882       13.022
# 3                           26.378        7.555
# 4                           27.080        7.013
#
#    SOx_emission_million_shots_tons  Volatile_compound_million_shots_tons  \
# 0                              NaN                                   NaN
# 1                              NaN                                   NaN
# 2                           31.218                                34.659
# 3                           28.044                                30.765
# 4                           25.926                                31.107
#
#    Overall_emission
# 0               NaN
# 1               NaN
# 2           309.823
# 3          1571.941
# 4          1673.902
#
# [5 rows x 29 columns]

# %% [markdown]
# Components of EDA
#
# To me, there are main components of exploring data:
#
# 1)Understanding your variables
#
# 2)Cleaning your dataset
#
# 3)Analyzing relationships between variables

# %%
co2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 29 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Sr.No.                                   38 non-null     float64
#  1   Year                                     38 non-null     float64
#  2   Jet Fuel_avi_BTU                         37 non-null     float64
#  3   Gasoline_avi_BTU                         37 non-null     float64
#  4   LDV_SWB_road_BTU                         37 non-null     float64
#  5   LDV_LWB_road_BTU                         35 non-null     float64
#  6   Combination_Truck_road_BTU               36 non-null     float64
#  7   Bus_Road_BTU                             37 non-null     float64
#  8   Railways_BTU                             37 non-null     float64
#  9   Water_BTU                                37 non-null     float64
#  10  Natural_Gas_BTU                          37 non-null     float64
#  11  LDV_SWB_EFF                              33 non-null     float64
#  12  LDV_LWB_EFF                              33 non-null     float64
#  13  Passenger_Car_EFF                        30 non-null     float64
#  14  Domestic_EFF                             30 non-null     float64
#  15  Imported_EFF                             30 non-null     float64
#  16  Light_Truck_EFF                          30 non-null     float64
#  17  Passenger_Car_Age                        22 non-null     float64
#  18  Light_Truck_Age                          22 non-null     float64
#  19  Light_vehicle_Age                        27 non-null     float64
#  20  Demand_petroleum_transportation)mil_lit  38 non-null     float64
#  21  Average_MC/15000_miles(dollars)          34 non-null     float64
#  22  CO2_emission_million_metric_tons         35 non-null     float64
#  23  CO_emission_million_shots_tons           34 non-null     float64
#  24  NOx_emission_million_shots_tons          34 non-null     float64
#  25  particulate                              34 non-null     float64
#  26  SOx_emission_million_shots_tons          34 non-null     float64
#  27  Volatile_compound_million_shots_tons     34 non-null     float64
#  28  Overall_emission                         36 non-null     float64
# dtypes: float64(29)
# memory usage: 8.7 KB

# %%
co2.describe()
# Out:
#           Sr.No.        Year   Jet Fuel_avi_BTU  Gasoline_avi_BTU  \
# count  38.000000    38.000000         37.000000         37.000000
# mean   19.500000  2000.289474       1503.527255         34.285880
# std    11.113055    15.305727        358.698281         10.103008
# min     1.000000  1960.000000        263.790000         22.150504
# 25%    10.250000  1993.250000       1389.501000         26.532600
# 50%    19.500000  2002.500000       1599.507000         32.892197
# 75%    28.750000  2011.750000       1754.838000         37.418260
# max    38.000000  2021.000000       1956.217500         66.230200
#
#        LDV_SWB_road_BTU  LDV_LWB_road_BTU  Combination_Truck_road_BTU  \
# count         37.000000         35.000000                   36.000000
# mean        9212.633512       4981.206450                 2806.450588
# std         1448.401091       1382.621576                  845.344627
# min         4952.283840       1481.134324                  800.864188
# 25%         8391.081006       4266.884762                 2218.370773
# 50%         9049.113356       4549.066789                 3121.791038
# 75%        10679.597549       6005.275844                 3466.368745
# max        11291.709467       7628.195070                 3722.771710
#
#        Bus_Road_BTU  Railways_BTU   Water_BTU  ...  Light_vehicle_Age  \
# count     37.000000     37.000000   37.000000  ...          27.000000
# mean     172.349972    490.264520  268.033279  ...          10.292593
# std       70.803675     44.185054   64.590103  ...           1.218109
# min       98.660622    399.229186   89.572412  ...           8.400000
# 25%      116.550547    469.705639  249.602593  ...           9.250000
# 50%      133.762122    493.472552  281.090318  ...          10.100000
# 75%      247.055297    510.370415  304.562824  ...          11.450000
# max      299.971076    575.901152  356.514136  ...          12.100000
#
#        Demand_petroleum_transportation)mil_lit  \
# count                                38.000000
# mean                             462983.167565
# std                              107156.302051
# min                                  35.070506
# 25%                              436483.585414
# 50%                              502694.143427
# 75%                              528023.473582
# max                              553756.463038
#
#        Average_MC/15000_miles(dollars)  CO2_emission_million_metric_tons  \
# count                        34.000000                         35.000000
# mean                       7259.147059                       1769.191543
# std                        1813.647975                        177.825120
# min                        2154.000000                       1290.801000
# 25%                        6236.000000                       1638.050500
# 50%                        7788.500000                       1813.662000
# 75%                        8540.250000                       1891.598000
# max                        9561.000000                       2026.325000
#
#        CO_emission_million_shots_tons  NOx_emission_million_shots_tons  \
# count                       34.000000                        34.000000
# mean                       107.566483                        19.868708
# std                         41.052900                         5.988197
# min                         52.118160                         8.568517
# 25%                         73.004787                        14.600799
# 50%                        100.812773                        22.073472
# 75%                        132.383035                        25.123750
# max                        204.042000                        27.080000
#
#        particulate  SOx_emission_million_shots_tons  \
# count    34.000000                        34.000000
# mean     21.357438                        14.408879
# std       6.131199                         8.124256
# min       7.013000                         1.984031
# 25%      18.441588                         6.792181
# 50%      21.538312                        14.920004
# 75%      23.626542                        20.745602
# max      41.323000                        31.218000
#
#        Volatile_compound_million_shots_tons  Overall_emission
# count                             34.000000         36.000000
# mean                              20.302797       1893.356954
# std                                4.704454        311.704269
# min                               13.678406        309.823000
# 25%                               17.590740       1840.293000
# 50%                               18.212114       1950.798980
# 75%                               22.438000       2031.734839
# max                               34.659000       2180.782527
#
# [8 rows x 29 columns]

# %%
columns = ['Sr.No.', 'Year ', 'Jet Fuel_avi_BTU', 'Gasoline_avi_BTU',
       'LDV_SWB_road_BTU', 'LDV_LWB_road_BTU', 'Combination_Truck_road_BTU',
       'Bus_Road_BTU', 'Railways_BTU', 'Water_BTU', 'Natural_Gas_BTU',
       'LDV_SWB_EFF', 'LDV_LWB_EFF', 'Passenger_Car_EFF', 'Domestic_EFF',
       'Imported_EFF', 'Light_Truck_EFF', 'Passenger_Car_Age',
       'Light_Truck_Age', 'Light_vehicle_Age',
       'Demand_petroleum_transportation)mil_lit',
       'Average_MC/15000_miles(dollars)', 'CO2_emission_million_metric_tons',
       'CO_emission_million_shots_tons', 'NOx_emission_million_shots_tons',
       'particulate', 'SOx_emission_million_shots_tons',
       'Volatile_compound_million_shots_tons', 'Overall_emission']

# %% [markdown]
# **Handling Missing Values**

# %%
# Finding missing values
co2.isnull().sum()
# Out:
# Sr.No.                                      0
# Year                                        0
# Jet Fuel_avi_BTU                            1
# Gasoline_avi_BTU                            1
# LDV_SWB_road_BTU                            1
# LDV_LWB_road_BTU                            3
# Combination_Truck_road_BTU                  2
# Bus_Road_BTU                                1
# Railways_BTU                                1
# Water_BTU                                   1
# Natural_Gas_BTU                             1
# LDV_SWB_EFF                                 5
# LDV_LWB_EFF                                 5
# Passenger_Car_EFF                           8
# Domestic_EFF                                8
# Imported_EFF                                8
# Light_Truck_EFF                             8
# Passenger_Car_Age                          16
# Light_Truck_Age                            16
# Light_vehicle_Age                          11
# Demand_petroleum_transportation)mil_lit     0
# Average_MC/15000_miles(dollars)             4
# CO2_emission_million_metric_tons            3
# CO_emission_million_shots_tons              4
# NOx_emission_million_shots_tons             4
# particulate                                 4
# SOx_emission_million_shots_tons             4
# Volatile_compound_million_shots_tons        4
# Overall_emission                            2
# dtype: int64

# %%
#We will first of all check all the missing value Percentage for each of the column
features_with_na = [features for features in co2.columns if co2[features].isnull().sum()>1]
# Print the % of missing values in each feature
for feature in features_with_na:
    print(feature, np.round(co2[feature].isnull().mean(),4),'%missing values')
# Out:
# LDV_LWB_road_BTU 0.0789 %missing values
# Combination_Truck_road_BTU 0.0526 %missing values
# LDV_SWB_EFF 0.1316 %missing values
# LDV_LWB_EFF 0.1316 %missing values
# Passenger_Car_EFF 0.2105 %missing values
# Domestic_EFF 0.2105 %missing values
# Imported_EFF 0.2105 %missing values
# Light_Truck_EFF 0.2105 %missing values
# Passenger_Car_Age 0.4211 %missing values
# Light_Truck_Age 0.4211 %missing values
# Light_vehicle_Age 0.2895 %missing values
# Average_MC/15000_miles(dollars) 0.1053 %missing values
# CO2_emission_million_metric_tons 0.0789 %missing values
# CO_emission_million_shots_tons 0.1053 %missing values
# NOx_emission_million_shots_tons 0.1053 %missing values
# particulate 0.1053 %missing values
# SOx_emission_million_shots_tons 0.1053 %missing values
# Volatile_compound_million_shots_tons 0.1053 %missing values
# Overall_emission 0.0526 %missing values

# %%
#Removing first and last rows as they have more na values
df = co2.iloc[1:37,:]
df
# Out:
#     Sr.No.   Year   Jet Fuel_avi_BTU  Gasoline_avi_BTU  LDV_SWB_road_BTU  \
# 1      2.0  1965.0        525.015000         35.098400       5980.980778
# 2      3.0  1970.0       1060.695000         66.230200       8164.903979
# 3      4.0  1975.0       1020.330000         49.522400       8931.556064
# 4      5.0  1980.0       1150.096472         62.504000       8442.341323
# 5      6.0  1985.0       1365.525967         50.604200       8624.481448
# 6      7.0  1990.0       1648.625177         42.430600       8391.081006
# 7      8.0  1991.0       1533.601535         42.550800       7758.585753
# 8      9.0  1992.0       1565.707168         37.742800       7893.995665
# 9     10.0  1993.0       1614.597453         32.213600       8088.694487
# 10    11.0  1994.0       1687.574851         31.973200       8145.937972
# 11    12.0  1995.0       1729.581739         34.497400       8211.742596
# 12    13.0  1996.0       1780.286144         34.677700       8311.152929
# 13    14.0  1997.0       1843.779676         35.122440       8431.325200
# 14    15.0  1998.0       1795.923251         37.418260       8648.676349
# 15    16.0  1999.0       1956.217500         41.517080       8825.640390
# 16    17.0  2000.0       1876.999500         40.002560       8813.907092
# 17    18.0  2001.0       1770.133500         33.562905       8871.281349
# 18    19.0  2002.0       1658.772000         33.258643       9101.115177
# 19    20.0  2003.0       1676.295000         32.739355       9099.177285
# 20    21.0  2004.0       1806.300000         32.802376       9094.143396
# 21    22.0  2005.0       1793.367000         35.464281       9335.150544
# 22    23.0  2006.0       1757.619000         34.068497       9049.113356
# 23    24.0  2007.0       1754.838000         32.892197      11130.649012
# 24    25.0  2008.0       1683.369000         29.815624      10354.058721
# 25    26.0  2009.0       1504.899000         27.335002      10361.415934
# 26    27.0  2010.0       1492.654500         26.532600      10490.773516
# 27    28.0  2011.0       1461.820500         25.958477      10679.597549
# 28    29.0  2012.0       1382.130000         24.815045      10716.441239
# 29    30.0  2013.0       1371.073500         23.711069      10714.923339
# 30    31.0  2014.0       1389.501000         25.186348      10796.801433
# 31    32.0  2015.0       1450.062000         23.516512      10883.374397
# 32    33.0  2016.0       1507.585500         24.821255      11060.732233
# 33    34.0  2017.0       1530.954000         24.811531      11086.832010
# 34    35.0  2018.0       1599.507000         27.882270      11071.363026
# 35    36.0  2019.0       1644.840000         24.059045      11291.709467
# 36    37.0  2020.0        976.441500         22.150504       9061.500092
#
#     LDV_LWB_road_BTU  Combination_Truck_road_BTU  Bus_Road_BTU  Railways_BTU  \
# 1                NaN                  800.864188    105.250250    493.472552
# 2        1481.134324                  883.853950     98.660622    487.015645
# 3        2295.138398                 1103.921827    126.666330    502.402317
# 4        2862.349250                 1568.168922    122.489519    536.335424
# 5        4002.009473                 1684.638041    100.279579    427.254910
# 6        4283.509658                 1940.564437    107.667192    427.941815
# 7        4596.958616                 2021.842131    103.923233    399.229186
# 8        4923.236416                 2070.871802    105.622055    412.829905
# 9        5154.400250                 2134.831988    111.783567    424.232528
# 10       5343.463567                 2246.217035    117.880761    458.028254
# 11       5485.583397                 2378.917896    116.395110    478.085880
# 12       5669.401393                 2417.523137    118.518656    491.686599
# 13       5940.649484                 2442.009444    123.482961    491.137075
# 14       6069.902203                 3026.151820    125.137736    492.236123
# 15       6347.589291                 3156.358528    137.897434    510.370415
# 16       6367.797098                 3087.223548    133.762122    508.309700
# 17       6437.920949                 3068.717667    123.401287    509.683510
# 18       6642.205911                 3185.128774    120.233435    512.431130
# 19       7308.342743                 2864.661794    116.550547    525.619706
# 20       7628.195070                 2909.827021    163.610394    557.629479
# 21       7081.127077                 3330.558609    134.726639    562.987338
# 22       7299.585807                 3380.823704    138.137561    575.901152
# 23       4132.923995                 3722.771710    243.352651    558.041622
# 24       4201.025101                 3676.046204    247.419624    533.862566
# 25       4295.477744                 3374.020771    239.016625    438.520152
# 26       4360.484647                 3599.758655    231.085527    480.009214
# 27       4250.259866                 3389.784456    232.891850    506.248985
# 28       4223.763969                 3365.040707    248.154636    494.571600
# 29       4229.098020                 3463.634662    254.600227    505.836842
# 30       4491.838566                 3502.446383    268.624941    531.252327
# 31       4382.900709                 3474.570994    268.005392    507.210652
# 32       4549.066789                 3555.009564    267.732030    465.034685
# 33       4506.725398                 3652.311275    282.710929    480.146595
# 34       4473.358122                 3647.680198    299.971076    502.264936
# 35       4574.446090                 3486.731921    294.774661    469.705639
# 36       4450.356376                 3418.737391    247.055297    406.510379
#
#      Water_BTU  ...  Light_vehicle_Age  \
# 1    89.572412  ...                NaN
# 2   112.515039  ...                NaN
# 3   150.844338  ...                NaN
# 4   203.049118  ...                NaN
# 5   233.408258  ...                NaN
# 6   283.670059  ...                NaN
# 7   281.090318  ...                NaN
# 8   304.792388  ...                NaN
# 9   296.022671  ...                NaN
# 10  300.774543  ...                NaN
# 11  321.335533  ...                8.4
# 12  342.187633  ...                8.5
# 13  353.591218  ...                8.6
# 14  356.514136  ...                8.8
# 15  332.370799  ...                8.8
# 16  310.676416  ...                8.9
# 17  280.813496  ...                8.9
# 18  285.604246  ...                9.6
# 19  304.562824  ...                9.7
# 20  293.946295  ...                9.8
# 21  275.526388  ...                9.8
# 22  261.455002  ...                9.9
# 23  264.318434  ...               10.0
# 24  272.484498  ...               10.1
# 25  262.807655  ...               10.3
# 26  275.151338  ...               10.6
# 27  293.087938  ...               10.9
# 28  242.934119  ...               11.2
# 29  230.184751  ...               11.4
# 30  218.902611  ...               11.4
# 31  332.091503  ...               11.5
# 32  308.464032  ...               11.6
# 33  300.265134  ...               11.7
# 34  303.975108  ...               11.7
# 35  280.519638  ...               11.8
# 36  249.602593  ...               11.9
#
#     Demand_petroleum_transportation)mil_lit  Average_MC/15000_miles(dollars)  \
# 1                             269470.995991                              NaN
# 2                             339177.522046                              NaN
# 3                             389881.923382                           2154.0
# 4                             396853.724860                           3176.0
# 5                             407271.871414                           3484.0
# 6                             430043.766812                           4954.0
# 7                             424806.490322                           5601.0
# 8                             434878.252752                           5824.0
# 9                             441299.583402                           5804.0
# 10                            449392.241588                           5916.0
# 11                            455205.835698                           6185.0
# 12                            464439.859954                           6389.0
# 13                            470636.961724                           6723.0
# 14                            484447.583157                           6908.0
# 15                            498846.775589                           7050.0
# 16                            499126.426686                           7363.0
# 17                            506261.860169                           7654.0
# 18                            519585.253652                           7534.0
# 19                            524688.496273                           7754.0
# 20                            534431.817430                           8431.0
# 21                            529914.352174                           8410.0
# 22                            529135.132685                           7834.0
# 23                            529568.751629                           7823.0
# 24                            514906.950025                           8121.0
# 25                            517644.722757                           8096.0
# 26                            521273.740460                           8487.0
# 27                            511580.806922                           8776.0
# 28                            509446.531070                           8946.0
# 29                            511564.541006                           9122.0
# 30                            529997.343547                           8876.0
# 31                            535005.960060                           8698.0
# 32                            548303.470215                           8558.0
# 33                            547276.174959                           8468.0
# 34                            549774.962911                           8849.0
# 35                            553756.463038                           9282.0
# 36                            483422.909983                           9561.0
#
#     CO2_emission_million_metric_tons  CO_emission_million_shots_tons  \
# 1                                NaN                             NaN
# 2                                NaN                      204.042000
# 3                           1290.801                      188.398000
# 4                           1397.368                      185.408000
# 5                           1423.027                      176.845000
# 6                           1586.738                      154.188000
# 7                           1566.980                      147.128000
# 8                           1590.597                      140.895000
# 9                           1603.874                      135.902000
# 10                          1644.050                      133.558000
# 11                          1678.552                      126.778000
# 12                          1728.610                      128.858139
# 13                          1747.712                      117.910141
# 14                          1785.253                      115.380100
# 15                          1831.809                      114.541264
# 16                          1887.665                      114.466633
# 17                          1859.394                      106.262327
# 18                          1898.731                      102.032848
# 19                          1916.584                       99.592698
# 20                          1971.599                       97.147153
# 21                          1992.366                       88.545890
# 22                          2023.293                       85.837099
# 23                          2026.325                       83.128309
# 24                          1895.531                       79.655089
# 25                          1831.553                       72.752525
# 26                          1847.157                       73.771049
# 27                          1812.879                       73.761574
# 28                          1775.791                       71.758191
# 29                          1795.477                       69.754808
# 30                          1813.662                       65.537023
# 31                          1836.994                       63.515540
# 32                          1869.325                       58.904365
# 33                          1886.292                       66.604683
# 34                          1917.760                       62.282826
# 35                          1923.853                       52.118160
# 36                          1632.051                             NaN
#
#     NOx_emission_million_shots_tons  particulate  \
# 1                               NaN          NaN
# 2                         26.882000    13.022000
# 3                         26.378000     7.555000
# 4                         27.080000     7.013000
# 5                         25.757000    41.323000
# 6                         25.527000    27.753000
# 7                         25.180000    27.345000
# 8                         25.261000    27.098000
# 9                         25.356000    27.364000
# 10                        25.350000    28.608000
# 11                        24.955000    25.820000
# 12                        24.787361    22.856997
# 13                        24.704957    22.908629
# 14                        24.347760    22.892668
# 15                        22.844743    23.383385
# 16                        22.598434    23.746877
# 17                        21.548511    23.707594
# 18                        23.958761    21.575879
# 19                        22.650576    21.664485
# 20                        21.331140    21.749046
# 21                        20.354764    21.301522
# 22                        19.227000    21.401134
# 23                        18.099236    21.500745
# 24                        16.909359    21.579932
# 25                        15.771705    21.199241
# 26                        14.846454    20.823025
# 27                        14.518914    20.722528
# 28                        13.878782    19.969523
# 29                        13.238651    19.216518
# 30                        12.589335    18.183278
# 31                        11.681853    17.525984
# 32                        10.303740    16.830369
# 33                         9.838189    17.034980
# 34                         9.211322    16.395386
# 35                         8.568517    15.082151
# 36                              NaN          NaN
#
#     SOx_emission_million_shots_tons  Volatile_compound_million_shots_tons  \
# 1                               NaN                                   NaN
# 2                         31.218000                             34.659000
# 3                         28.044000                             30.765000
# 4                         25.926000                             31.107000
# 5                         23.307000                             27.403000
# 6                         23.077000                             24.108000
# 7                         22.374851                             23.577000
# 8                         22.082000                             23.066000
# 9                         21.773000                             22.730000
# 10                        21.346000                             22.570000
# 11                        18.619000                             22.042000
# 12                        18.385268                             20.871235
# 13                        18.839865                             19.530183
# 14                        18.944408                             18.781439
# 15                        17.545486                             18.269942
# 16                        16.346998                             17.512342
# 17                        15.931656                             17.111263
# 18                        15.032065                             20.289449
# 19                        14.807944                             19.910970
# 20                        14.571443                             19.513839
# 21                        14.545748                             17.753006
# 22                        13.122556                             17.901738
# 23                        11.699364                             18.050470
# 24                        10.323658                             17.758856
# 25                         9.089238                             17.593197
# 26                         7.732208                             17.835014
# 27                         6.478839                             18.154287
# 28                         5.079293                             17.872104
# 29                         4.873418                             17.589921
# 30                         4.674456                             16.882678
# 31                         3.945029                             16.329780
# 32                         3.204068                             15.458595
# 33                         2.539499                             17.184851
# 34                         2.438492                             16.434534
# 35                         1.984031                             13.678406
# 36                              NaN                                   NaN
#
#     Overall_emission
# 1                NaN
# 2         309.823000
# 3        1571.941000
# 4        1673.902000
# 5        1717.662000
# 6        1841.391000
# 7        1812.584851
# 8        1828.999000
# 9        1836.999000
# 10       1875.482000
# 11       1896.766000
# 12       1944.369001
# 13       1951.605775
# 14       1985.599375
# 15       2028.393820
# 16       2082.336284
# 17       2043.955351
# 18       2081.620001
# 19       2095.210674
# 20       2145.911621
# 21       2154.866930
# 22       2180.782527
# 23       2178.803124
# 24       2041.757895
# 25       1967.958906
# 26       1982.164750
# 27       1946.515142
# 28       1904.348893
# 29       1920.150316
# 30       1931.528769
# 31       1949.992185
# 32       1974.026137
# 33       1999.494202
# 34       2024.522562
# 35       2015.284264
# 36       1632.051000
#
# [36 rows x 29 columns]

# %%
df.shape
# Out:
# (36, 29)

# %% [markdown]
# **Plotting the Histogram**

# %%
cols = 29
rows = 38
num_cols = df.select_dtypes(exclude = 'object').columns

fig = plt.figure(figsize = (cols*3, rows*3))

for i, col in enumerate(num_cols):
    ax = fig.add_subplot(rows,cols,i+1)
    sns.histplot(x = co2[col], ax = ax)

fig.tight_layout()
plt.show()

# %% [markdown]
# **Plotting Boxplot**

# %%
cols = 29
rows = 38
num_cols = df.select_dtypes(exclude = 'object').columns

fig = plt.figure(figsize=(40, 40))

for i, col in enumerate(num_cols):
    ax = fig.add_subplot(rows, cols, i+1)

    sns.boxplot(co2[col], ax = ax)

fig.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   if sys.path[0] == '':

# %%
for i in df.columns:
    plt.figure()
    plt.tight_layout()
    sns.set(rc={"figure.figsize":(8, 5)})
    f, (ax_box, ax_hist) = plt.subplots(2, sharex=True)
    plt.gca().set(xlabel= i,ylabel='Frequency')
    sns.boxplot(df[i], ax=ax_box , linewidth= 1.0)
    sns.histplot(df[i], ax=ax_hist , bins = 10,kde=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
for i in df.columns:
    plt.figure()
    plt.tight_layout()
    sns.set(rc={"figure.figsize":(8, 5)})
    f, (ax_vio, ax_hist) = plt.subplots(2, sharex=True)
    plt.gca().set(xlabel= i,ylabel='Frequency')
    sns.violinplot(df[i], ax=ax_vio , linewidth= 1.0)
    sns.histplot(df[i], ax=ax_hist , bins = 10,kde=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
cols = 29
rows = 38
num_cols = co2.select_dtypes(exclude = 'object').columns

fig = plt.figure(figsize = (cols*3, rows*3))

for i, col in enumerate(num_cols):
    ax = fig.add_subplot(rows,cols,i+1)
    sns.swarmplot(x = co2[col], ax = ax)
    
fig.tight_layout()
plt.show()

# %%
# As the data is not normal we can continue with median imputation 

from sklearn.impute import SimpleImputer
median_imputer = SimpleImputer(missing_values=np.nan, strategy='median')
median_imputer.fit(df)
df = median_imputer.transform(df)

# %%
data = pd.DataFrame(df, columns=columns)
data
# Out:
#     Sr.No.   Year   Jet Fuel_avi_BTU  Gasoline_avi_BTU  LDV_SWB_road_BTU  \
# 0      2.0  1965.0        525.015000         35.098400       5980.980778
# 1      3.0  1970.0       1060.695000         66.230200       8164.903979
# 2      4.0  1975.0       1020.330000         49.522400       8931.556064
# 3      5.0  1980.0       1150.096472         62.504000       8442.341323
# 4      6.0  1985.0       1365.525967         50.604200       8624.481448
# 5      7.0  1990.0       1648.625177         42.430600       8391.081006
# 6      8.0  1991.0       1533.601535         42.550800       7758.585753
# 7      9.0  1992.0       1565.707168         37.742800       7893.995665
# 8     10.0  1993.0       1614.597453         32.213600       8088.694487
# 9     11.0  1994.0       1687.574851         31.973200       8145.937972
# 10    12.0  1995.0       1729.581739         34.497400       8211.742596
# 11    13.0  1996.0       1780.286144         34.677700       8311.152929
# 12    14.0  1997.0       1843.779676         35.122440       8431.325200
# 13    15.0  1998.0       1795.923251         37.418260       8648.676349
# 14    16.0  1999.0       1956.217500         41.517080       8825.640390
# 15    17.0  2000.0       1876.999500         40.002560       8813.907092
# 16    18.0  2001.0       1770.133500         33.562905       8871.281349
# 17    19.0  2002.0       1658.772000         33.258643       9101.115177
# 18    20.0  2003.0       1676.295000         32.739355       9099.177285
# 19    21.0  2004.0       1806.300000         32.802376       9094.143396
# 20    22.0  2005.0       1793.367000         35.464281       9335.150544
# 21    23.0  2006.0       1757.619000         34.068497       9049.113356
# 22    24.0  2007.0       1754.838000         32.892197      11130.649012
# 23    25.0  2008.0       1683.369000         29.815624      10354.058721
# 24    26.0  2009.0       1504.899000         27.335002      10361.415934
# 25    27.0  2010.0       1492.654500         26.532600      10490.773516
# 26    28.0  2011.0       1461.820500         25.958477      10679.597549
# 27    29.0  2012.0       1382.130000         24.815045      10716.441239
# 28    30.0  2013.0       1371.073500         23.711069      10714.923339
# 29    31.0  2014.0       1389.501000         25.186348      10796.801433
# 30    32.0  2015.0       1450.062000         23.516512      10883.374397
# 31    33.0  2016.0       1507.585500         24.821255      11060.732233
# 32    34.0  2017.0       1530.954000         24.811531      11086.832010
# 33    35.0  2018.0       1599.507000         27.882270      11071.363026
# 34    36.0  2019.0       1644.840000         24.059045      11291.709467
# 35    37.0  2020.0        976.441500         22.150504       9061.500092
#
#     LDV_LWB_road_BTU  Combination_Truck_road_BTU  Bus_Road_BTU  Railways_BTU  \
# 0        4549.066789                  800.864188    105.250250    493.472552
# 1        1481.134324                  883.853950     98.660622    487.015645
# 2        2295.138398                 1103.921827    126.666330    502.402317
# 3        2862.349250                 1568.168922    122.489519    536.335424
# 4        4002.009473                 1684.638041    100.279579    427.254910
# 5        4283.509658                 1940.564437    107.667192    427.941815
# 6        4596.958616                 2021.842131    103.923233    399.229186
# 7        4923.236416                 2070.871802    105.622055    412.829905
# 8        5154.400250                 2134.831988    111.783567    424.232528
# 9        5343.463567                 2246.217035    117.880761    458.028254
# 10       5485.583397                 2378.917896    116.395110    478.085880
# 11       5669.401393                 2417.523137    118.518656    491.686599
# 12       5940.649484                 2442.009444    123.482961    491.137075
# 13       6069.902203                 3026.151820    125.137736    492.236123
# 14       6347.589291                 3156.358528    137.897434    510.370415
# 15       6367.797098                 3087.223548    133.762122    508.309700
# 16       6437.920949                 3068.717667    123.401287    509.683510
# 17       6642.205911                 3185.128774    120.233435    512.431130
# 18       7308.342743                 2864.661794    116.550547    525.619706
# 19       7628.195070                 2909.827021    163.610394    557.629479
# 20       7081.127077                 3330.558609    134.726639    562.987338
# 21       7299.585807                 3380.823704    138.137561    575.901152
# 22       4132.923995                 3722.771710    243.352651    558.041622
# 23       4201.025101                 3676.046204    247.419624    533.862566
# 24       4295.477744                 3374.020771    239.016625    438.520152
# 25       4360.484647                 3599.758655    231.085527    480.009214
# 26       4250.259866                 3389.784456    232.891850    506.248985
# 27       4223.763969                 3365.040707    248.154636    494.571600
# 28       4229.098020                 3463.634662    254.600227    505.836842
# 29       4491.838566                 3502.446383    268.624941    531.252327
# 30       4382.900709                 3474.570994    268.005392    507.210652
# 31       4549.066789                 3555.009564    267.732030    465.034685
# 32       4506.725398                 3652.311275    282.710929    480.146595
# 33       4473.358122                 3647.680198    299.971076    502.264936
# 34       4574.446090                 3486.731921    294.774661    469.705639
# 35       4450.356376                 3418.737391    247.055297    406.510379
#
#      Water_BTU  ...  Light_vehicle_Age  \
# 0    89.572412  ...              10.05
# 1   112.515039  ...              10.05
# 2   150.844338  ...              10.05
# 3   203.049118  ...              10.05
# 4   233.408258  ...              10.05
# 5   283.670059  ...              10.05
# 6   281.090318  ...              10.05
# 7   304.792388  ...              10.05
# 8   296.022671  ...              10.05
# 9   300.774543  ...              10.05
# 10  321.335533  ...               8.40
# 11  342.187633  ...               8.50
# 12  353.591218  ...               8.60
# 13  356.514136  ...               8.80
# 14  332.370799  ...               8.80
# 15  310.676416  ...               8.90
# 16  280.813496  ...               8.90
# 17  285.604246  ...               9.60
# 18  304.562824  ...               9.70
# 19  293.946295  ...               9.80
# 20  275.526388  ...               9.80
# 21  261.455002  ...               9.90
# 22  264.318434  ...              10.00
# 23  272.484498  ...              10.10
# 24  262.807655  ...              10.30
# 25  275.151338  ...              10.60
# 26  293.087938  ...              10.90
# 27  242.934119  ...              11.20
# 28  230.184751  ...              11.40
# 29  218.902611  ...              11.40
# 30  332.091503  ...              11.50
# 31  308.464032  ...              11.60
# 32  300.265134  ...              11.70
# 33  303.975108  ...              11.70
# 34  280.519638  ...              11.80
# 35  249.602593  ...              11.90
#
#     Demand_petroleum_transportation)mil_lit  Average_MC/15000_miles(dollars)  \
# 0                             269470.995991                           7788.5
# 1                             339177.522046                           7788.5
# 2                             389881.923382                           2154.0
# 3                             396853.724860                           3176.0
# 4                             407271.871414                           3484.0
# 5                             430043.766812                           4954.0
# 6                             424806.490322                           5601.0
# 7                             434878.252752                           5824.0
# 8                             441299.583402                           5804.0
# 9                             449392.241588                           5916.0
# 10                            455205.835698                           6185.0
# 11                            464439.859954                           6389.0
# 12                            470636.961724                           6723.0
# 13                            484447.583157                           6908.0
# 14                            498846.775589                           7050.0
# 15                            499126.426686                           7363.0
# 16                            506261.860169                           7654.0
# 17                            519585.253652                           7534.0
# 18                            524688.496273                           7754.0
# 19                            534431.817430                           8431.0
# 20                            529914.352174                           8410.0
# 21                            529135.132685                           7834.0
# 22                            529568.751629                           7823.0
# 23                            514906.950025                           8121.0
# 24                            517644.722757                           8096.0
# 25                            521273.740460                           8487.0
# 26                            511580.806922                           8776.0
# 27                            509446.531070                           8946.0
# 28                            511564.541006                           9122.0
# 29                            529997.343547                           8876.0
# 30                            535005.960060                           8698.0
# 31                            548303.470215                           8558.0
# 32                            547276.174959                           8468.0
# 33                            549774.962911                           8849.0
# 34                            553756.463038                           9282.0
# 35                            483422.909983                           9561.0
#
#     CO2_emission_million_metric_tons  CO_emission_million_shots_tons  \
# 0                          1822.6075                      100.812773
# 1                          1822.6075                      204.042000
# 2                          1290.8010                      188.398000
# 3                          1397.3680                      185.408000
# 4                          1423.0270                      176.845000
# 5                          1586.7380                      154.188000
# 6                          1566.9800                      147.128000
# 7                          1590.5970                      140.895000
# 8                          1603.8740                      135.902000
# 9                          1644.0500                      133.558000
# 10                         1678.5520                      126.778000
# 11                         1728.6100                      128.858139
# 12                         1747.7120                      117.910141
# 13                         1785.2530                      115.380100
# 14                         1831.8090                      114.541264
# 15                         1887.6650                      114.466633
# 16                         1859.3940                      106.262327
# 17                         1898.7310                      102.032848
# 18                         1916.5840                       99.592698
# 19                         1971.5990                       97.147153
# 20                         1992.3660                       88.545890
# 21                         2023.2930                       85.837099
# 22                         2026.3250                       83.128309
# 23                         1895.5310                       79.655089
# 24                         1831.5530                       72.752525
# 25                         1847.1570                       73.771049
# 26                         1812.8790                       73.761574
# 27                         1775.7910                       71.758191
# 28                         1795.4770                       69.754808
# 29                         1813.6620                       65.537023
# 30                         1836.9940                       63.515540
# 31                         1869.3250                       58.904365
# 32                         1886.2920                       66.604683
# 33                         1917.7600                       62.282826
# 34                         1923.8530                       52.118160
# 35                         1632.0510                      100.812773
#
#     NOx_emission_million_shots_tons  particulate  \
# 0                         22.073472    21.538312
# 1                         26.882000    13.022000
# 2                         26.378000     7.555000
# 3                         27.080000     7.013000
# 4                         25.757000    41.323000
# 5                         25.527000    27.753000
# 6                         25.180000    27.345000
# 7                         25.261000    27.098000
# 8                         25.356000    27.364000
# 9                         25.350000    28.608000
# 10                        24.955000    25.820000
# 11                        24.787361    22.856997
# 12                        24.704957    22.908629
# 13                        24.347760    22.892668
# 14                        22.844743    23.383385
# 15                        22.598434    23.746877
# 16                        21.548511    23.707594
# 17                        23.958761    21.575879
# 18                        22.650576    21.664485
# 19                        21.331140    21.749046
# 20                        20.354764    21.301522
# 21                        19.227000    21.401134
# 22                        18.099236    21.500745
# 23                        16.909359    21.579932
# 24                        15.771705    21.199241
# 25                        14.846454    20.823025
# 26                        14.518914    20.722528
# 27                        13.878782    19.969523
# 28                        13.238651    19.216518
# 29                        12.589335    18.183278
# 30                        11.681853    17.525984
# 31                        10.303740    16.830369
# 32                         9.838189    17.034980
# 33                         9.211322    16.395386
# 34                         8.568517    15.082151
# 35                        22.073472    21.538312
#
#     SOx_emission_million_shots_tons  Volatile_compound_million_shots_tons  \
# 0                         14.920004                             18.212114
# 1                         31.218000                             34.659000
# 2                         28.044000                             30.765000
# 3                         25.926000                             31.107000
# 4                         23.307000                             27.403000
# 5                         23.077000                             24.108000
# 6                         22.374851                             23.577000
# 7                         22.082000                             23.066000
# 8                         21.773000                             22.730000
# 9                         21.346000                             22.570000
# 10                        18.619000                             22.042000
# 11                        18.385268                             20.871235
# 12                        18.839865                             19.530183
# 13                        18.944408                             18.781439
# 14                        17.545486                             18.269942
# 15                        16.346998                             17.512342
# 16                        15.931656                             17.111263
# 17                        15.032065                             20.289449
# 18                        14.807944                             19.910970
# 19                        14.571443                             19.513839
# 20                        14.545748                             17.753006
# 21                        13.122556                             17.901738
# 22                        11.699364                             18.050470
# 23                        10.323658                             17.758856
# 24                         9.089238                             17.593197
# 25                         7.732208                             17.835014
# 26                         6.478839                             18.154287
# 27                         5.079293                             17.872104
# 28                         4.873418                             17.589921
# 29                         4.674456                             16.882678
# 30                         3.945029                             16.329780
# 31                         3.204068                             15.458595
# 32                         2.539499                             17.184851
# 33                         2.438492                             16.434534
# 34                         1.984031                             13.678406
# 35                        14.920004                             18.212114
#
#     Overall_emission
# 0        1951.605775
# 1         309.823000
# 2        1571.941000
# 3        1673.902000
# 4        1717.662000
# 5        1841.391000
# 6        1812.584851
# 7        1828.999000
# 8        1836.999000
# 9        1875.482000
# 10       1896.766000
# 11       1944.369001
# 12       1951.605775
# 13       1985.599375
# 14       2028.393820
# 15       2082.336284
# 16       2043.955351
# 17       2081.620001
# 18       2095.210674
# 19       2145.911621
# 20       2154.866930
# 21       2180.782527
# 22       2178.803124
# 23       2041.757895
# 24       1967.958906
# 25       1982.164750
# 26       1946.515142
# 27       1904.348893
# 28       1920.150316
# 29       1931.528769
# 30       1949.992185
# 31       1974.026137
# 32       1999.494202
# 33       2024.522562
# 34       2015.284264
# 35       1632.051000
#
# [36 rows x 29 columns]

# %%
data.isnull().sum()
# Out:
# Sr.No.                                     0
# Year                                       0
# Jet Fuel_avi_BTU                           0
# Gasoline_avi_BTU                           0
# LDV_SWB_road_BTU                           0
# LDV_LWB_road_BTU                           0
# Combination_Truck_road_BTU                 0
# Bus_Road_BTU                               0
# Railways_BTU                               0
# Water_BTU                                  0
# Natural_Gas_BTU                            0
# LDV_SWB_EFF                                0
# LDV_LWB_EFF                                0
# Passenger_Car_EFF                          0
# Domestic_EFF                               0
# Imported_EFF                               0
# Light_Truck_EFF                            0
# Passenger_Car_Age                          0
# Light_Truck_Age                            0
# Light_vehicle_Age                          0
# Demand_petroleum_transportation)mil_lit    0
# Average_MC/15000_miles(dollars)            0
# CO2_emission_million_metric_tons           0
# CO_emission_million_shots_tons             0
# NOx_emission_million_shots_tons            0
# particulate                                0
# SOx_emission_million_shots_tons            0
# Volatile_compound_million_shots_tons       0
# Overall_emission                           0
# dtype: int64

# %%
#All the null values are imputed so let's calculate overall emission

data['overall_emission'] = data['CO2_emission_million_metric_tons'] + data['CO_emission_million_shots_tons'] + data['NOx_emission_million_shots_tons'] + data['particulate'] +data['SOx_emission_million_shots_tons'] +data['Volatile_compound_million_shots_tons']

# %%
data.head()
# Out:
#    Sr.No.   Year   Jet Fuel_avi_BTU  Gasoline_avi_BTU  LDV_SWB_road_BTU  \
# 0     2.0  1965.0        525.015000           35.0984       5980.980778
# 1     3.0  1970.0       1060.695000           66.2302       8164.903979
# 2     4.0  1975.0       1020.330000           49.5224       8931.556064
# 3     5.0  1980.0       1150.096472           62.5040       8442.341323
# 4     6.0  1985.0       1365.525967           50.6042       8624.481448
#
#    LDV_LWB_road_BTU  Combination_Truck_road_BTU  Bus_Road_BTU  Railways_BTU  \
# 0       4549.066789                  800.864188    105.250250    493.472552
# 1       1481.134324                  883.853950     98.660622    487.015645
# 2       2295.138398                 1103.921827    126.666330    502.402317
# 3       2862.349250                 1568.168922    122.489519    536.335424
# 4       4002.009473                 1684.638041    100.279579    427.254910
#
#     Water_BTU  ...  Demand_petroleum_transportation)mil_lit  \
# 0   89.572412  ...                            269470.995991
# 1  112.515039  ...                            339177.522046
# 2  150.844338  ...                            389881.923382
# 3  203.049118  ...                            396853.724860
# 4  233.408258  ...                            407271.871414
#
#    Average_MC/15000_miles(dollars)  CO2_emission_million_metric_tons  \
# 0                           7788.5                         1822.6075
# 1                           7788.5                         1822.6075
# 2                           2154.0                         1290.8010
# 3                           3176.0                         1397.3680
# 4                           3484.0                         1423.0270
#
#    CO_emission_million_shots_tons  NOx_emission_million_shots_tons  \
# 0                      100.812773                        22.073472
# 1                      204.042000                        26.882000
# 2                      188.398000                        26.378000
# 3                      185.408000                        27.080000
# 4                      176.845000                        25.757000
#
#    particulate  SOx_emission_million_shots_tons  \
# 0    21.538312                        14.920004
# 1    13.022000                        31.218000
# 2     7.555000                        28.044000
# 3     7.013000                        25.926000
# 4    41.323000                        23.307000
#
#    Volatile_compound_million_shots_tons  Overall_emission  overall_emission
# 0                             18.212114       1951.605775       2000.164176
# 1                             34.659000        309.823000       2132.430500
# 2                             30.765000       1571.941000       1571.941000
# 3                             31.107000       1673.902000       1673.902000
# 4                             27.403000       1717.662000       1717.662000
#
# [5 rows x 30 columns]

# %%
#Pearson Correlation 
plt.figure(figsize=(22, 20))
cor = data.corr()
sns.heatmap(cor,annot=True, cmap = plt.cm.CMRmap_r)
plt.show()

# %%
dfCorr = data.corr()
filteredDf = dfCorr[((dfCorr >= .70) | (dfCorr <= -.70)) & (dfCorr !=1.000)]
plt.figure(figsize=(30,18))
sns.heatmap(filteredDf, annot=True, cmap= plt.cm.CMRmap_r, annot_kws={
                'fontsize': 16,
                'fontweight': 'bold',
                'fontfamily': 'serif'
            })
plt.show()

# %%
#with the follwing function we can select highly correlated features 
#it will remove the features that is correlated with anything other feature
def correlation(data, threshold):
    col_corr = set()   #set of all the names of correlated columns
    corr_matrix = data.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if (corr_matrix.iloc[i,j]) > threshold: #we interested in absolute coefficient values 
                colname = corr_matrix.columns[i]   #getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(data, 0.7)
len(set(corr_features))
# Out:
# 19

# %%
corr_features
# Out:
# {'Average_MC/15000_miles(dollars)',
#  'Bus_Road_BTU',
#  'CO2_emission_million_metric_tons',
#  'CO_emission_million_shots_tons',
#  'Combination_Truck_road_BTU',
#  'Demand_petroleum_transportation)mil_lit',
#  'Domestic_EFF',
#  'Imported_EFF',
#  'LDV_SWB_EFF',
#  'LDV_SWB_road_BTU',
#  'Light_Truck_Age',
#  'Light_Truck_EFF',
#  'Light_vehicle_Age',
#  'NOx_emission_million_shots_tons',
#  'SOx_emission_million_shots_tons',
#  'Volatile_compound_million_shots_tons',
#  'Water_BTU',
#  'Year ',
#  'overall_emission'}

# %% [markdown]
# **We can drop the unnecessary columns from the dataset which has not any correlation with the target variable. eg. sr.no.**

# %% [markdown]
# **Some of the features are strongly correlated with each other but they are not affecting to the target variable such as 'Domestic_EFF','Imported_EFF', 'LDV_SWB_EFF', 'Light_Truck_Age' so we will drop these columns**

# %% [markdown]
# **Outlier Treatment**

# %%
data.columns
# Out:
# Index(['Sr.No.', 'Year ', 'Jet Fuel_avi_BTU', 'Gasoline_avi_BTU',
#        'LDV_SWB_road_BTU', 'LDV_LWB_road_BTU', 'Combination_Truck_road_BTU',
#        'Bus_Road_BTU', 'Railways_BTU', 'Water_BTU', 'Natural_Gas_BTU',
#        'LDV_SWB_EFF', 'LDV_LWB_EFF', 'Passenger_Car_EFF', 'Domestic_EFF',
#        'Imported_EFF', 'Light_Truck_EFF', 'Passenger_Car_Age',
#        'Light_Truck_Age', 'Light_vehicle_Age',
#        'Demand_petroleum_transportation)mil_lit',
#        'Average_MC/15000_miles(dollars)', 'CO2_emission_million_metric_tons',
#        'CO_emission_million_shots_tons', 'NOx_emission_million_shots_tons',
#        'particulate', 'SOx_emission_million_shots_tons',
#        'Volatile_compound_million_shots_tons', 'Overall_emission',
#        'overall_emission'],
#       dtype='object')

# %%
columns1 = ['Sr.No.', 'Year ', 'Jet Fuel_avi_BTU', 'Gasoline_avi_BTU',
       'LDV_SWB_road_BTU', 'LDV_LWB_road_BTU', 'Combination_Truck_road_BTU',
       'Bus_Road_BTU', 'Railways_BTU', 'Water_BTU', 'Natural_Gas_BTU',
       'LDV_SWB_EFF', 'LDV_LWB_EFF', 'Passenger_Car_EFF', 'Domestic_EFF',
       'Imported_EFF', 'Light_Truck_EFF', 'Passenger_Car_Age',
       'Light_Truck_Age', 'Light_vehicle_Age',
       'Demand_petroleum_transportation)mil_lit',
       'Average_MC/15000_miles(dollars)', 'CO2_emission_million_metric_tons',
       'CO_emission_million_shots_tons', 'NOx_emission_million_shots_tons',
       'particulate', 'SOx_emission_million_shots_tons',
       'Volatile_compound_million_shots_tons', 'Overall_emission',
       'overall_emission']

# %%
# !pip install feature-engine
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting feature-engine
#   Downloading feature_engine-1.4.0-py2.py3-none-any.whl (276 kB)
#      |████████████████████████████████| 276 kB 16.8 MB/s
# Requirement already satisfied: numpy>=1.18.2 in /usr/local/lib/python3.7/dist-packages (from feature-engine) (1.21.6)
# Requirement already satisfied: pandas>=1.0.3 in /usr/local/lib/python3.7/dist-packages (from feature-engine) (1.3.5)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from feature-engine) (1.7.3)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from feature-engine) (1.0.2)
# Requirement already satisfied: statsmodels>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from feature-engine) (0.12.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.3->feature-engine) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.3->feature-engine) (2022.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.0.3->feature-engine) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=1.0.0->feature-engine) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=1.0.0->feature-engine) (1.1.0)
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.7/dist-packages (from statsmodels>=0.11.1->feature-engine) (0.5.2)
# Installing collected packages: feature-engine
# Successfully installed feature-engine-1.4.0

# %%
from feature_engine.outliers import Winsorizer

# %%
IQR = data.quantile(0.75) - data.quantile(0.25)
lower_limit = data.quantile(0.25) - (IQR * 1.5)
upper_limit = data.quantile(0.75) + (IQR * 1.5)

for i in columns1:
    winsor = Winsorizer(capping_method='iqr',
                            tail='both',
                            fold=1.5,
                            variables=[i])
    data[i] = winsor.fit_transform(data[[i]])

# %%
import seaborn as sns
for feature in data:
    sns.boxplot(data[feature])
    plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
data1 = data.drop({'Sr.No.','Railways_BTU', 'Water_BTU', 'Natural_Gas_BTU',
       'LDV_SWB_EFF', 'LDV_LWB_EFF','Domestic_EFF','Imported_EFF', 'Light_Truck_EFF','Light_Truck_Age', 'Light_vehicle_Age',
       'particulate', 'Overall_emission'},axis=1)

# %%
data1.head()
# Out:
#     Year   Jet Fuel_avi_BTU  Gasoline_avi_BTU  LDV_SWB_road_BTU  \
# 0  1967.5        954.004500         35.098400       5980.980778
# 1  1970.0       1060.695000         54.164884       8164.903979
# 2  1975.0       1020.330000         49.522400       8931.556064
# 3  1980.0       1150.096472         54.164884       8442.341323
# 4  1985.0       1365.525967         50.604200       8624.481448
#
#    LDV_LWB_road_BTU  Combination_Truck_road_BTU  Bus_Road_BTU  \
# 0       4549.066789                  800.864188    105.250250
# 1       1728.549029                  883.853950     98.660622
# 2       2295.138398                 1103.921827    126.666330
# 3       2862.349250                 1568.168922    122.489519
# 4       4002.009473                 1684.638041    100.279579
#
#    Passenger_Car_EFF  Passenger_Car_Age  \
# 0               27.6              10.15
# 1               28.0              10.15
# 2               28.4              10.15
# 3               27.9              10.15
# 4               28.4              10.15
#
#    Demand_petroleum_transportation)mil_lit  Average_MC/15000_miles(dollars)  \
# 0                            324557.386472                         7788.500
# 1                            339177.522046                         7788.500
# 2                            389881.923382                         3087.875
# 3                            396853.724860                         3176.000
# 4                            407271.871414                         3484.000
#
#    CO2_emission_million_metric_tons  CO_emission_million_shots_tons  \
# 0                         1822.6075                      100.812773
# 1                         1822.6075                      204.042000
# 2                         1340.3690                      188.398000
# 3                         1397.3680                      185.408000
# 4                         1423.0270                      176.845000
#
#    NOx_emission_million_shots_tons  SOx_emission_million_shots_tons  \
# 0                        22.073472                        14.920004
# 1                        26.882000                        31.218000
# 2                        26.378000                        28.044000
# 3                        27.080000                        25.926000
# 4                        25.757000                        23.307000
#
#    Volatile_compound_million_shots_tons  overall_emission
# 0                             18.212114       2000.164176
# 1                             29.046433       2132.430500
# 2                             29.046433       1665.151612
# 3                             29.046433       1673.902000
# 4                             27.403000       1717.662000

# %%
data1.shape
# Out:
# (36, 17)

# %%
data1.columns
# Out:
# Index(['Year ', 'Jet Fuel_avi_BTU', 'Gasoline_avi_BTU', 'LDV_SWB_road_BTU',
#        'LDV_LWB_road_BTU', 'Combination_Truck_road_BTU', 'Bus_Road_BTU',
#        'Passenger_Car_EFF', 'Passenger_Car_Age',
#        'Demand_petroleum_transportation)mil_lit',
#        'Average_MC/15000_miles(dollars)', 'CO2_emission_million_metric_tons',
#        'CO_emission_million_shots_tons', 'NOx_emission_million_shots_tons',
#        'SOx_emission_million_shots_tons',
#        'Volatile_compound_million_shots_tons', 'overall_emission'],
#       dtype='object')

# %%
data2 = data1.rename({'Year ':'year'},axis = 1)
data2
# Out:
#       year  Jet Fuel_avi_BTU  Gasoline_avi_BTU  LDV_SWB_road_BTU  \
# 0   1967.5        954.004500         35.098400       5980.980778
# 1   1970.0       1060.695000         54.164884       8164.903979
# 2   1975.0       1020.330000         49.522400       8931.556064
# 3   1980.0       1150.096472         54.164884       8442.341323
# 4   1985.0       1365.525967         50.604200       8624.481448
# 5   1990.0       1648.625177         42.430600       8391.081006
# 6   1991.0       1533.601535         42.550800       7758.585753
# 7   1992.0       1565.707168         37.742800       7893.995665
# 8   1993.0       1614.597453         32.213600       8088.694487
# 9   1994.0       1687.574851         31.973200       8145.937972
# 10  1995.0       1729.581739         34.497400       8211.742596
# 11  1996.0       1780.286144         34.677700       8311.152929
# 12  1997.0       1843.779676         35.122440       8431.325200
# 13  1998.0       1795.923251         37.418260       8648.676349
# 14  1999.0       1956.217500         41.517080       8825.640390
# 15  2000.0       1876.999500         40.002560       8813.907092
# 16  2001.0       1770.133500         33.562905       8871.281349
# 17  2002.0       1658.772000         33.258643       9101.115177
# 18  2003.0       1676.295000         32.739355       9099.177285
# 19  2004.0       1806.300000         32.802376       9094.143396
# 20  2005.0       1793.367000         35.464281       9335.150544
# 21  2006.0       1757.619000         34.068497       9049.113356
# 22  2007.0       1754.838000         32.892197      11130.649012
# 23  2008.0       1683.369000         29.815624      10354.058721
# 24  2009.0       1504.899000         27.335002      10361.415934
# 25  2010.0       1492.654500         26.532600      10490.773516
# 26  2011.0       1461.820500         25.958477      10679.597549
# 27  2012.0       1382.130000         24.815045      10716.441239
# 28  2013.0       1371.073500         23.711069      10714.923339
# 29  2014.0       1389.501000         25.186348      10796.801433
# 30  2015.0       1450.062000         23.516512      10883.374397
# 31  2016.0       1507.585500         24.821255      11060.732233
# 32  2017.0       1530.954000         24.811531      11086.832010
# 33  2018.0       1599.507000         27.882270      11071.363026
# 34  2019.0       1644.840000         24.059045      11291.709467
# 35  2020.0        976.441500         22.150504       9061.500092
#
#     LDV_LWB_road_BTU  Combination_Truck_road_BTU  Bus_Road_BTU  \
# 0        4549.066789                  800.864188    105.250250
# 1        1728.549029                  883.853950     98.660622
# 2        2295.138398                 1103.921827    126.666330
# 3        2862.349250                 1568.168922    122.489519
# 4        4002.009473                 1684.638041    100.279579
# 5        4283.509658                 1940.564437    107.667192
# 6        4596.958616                 2021.842131    103.923233
# 7        4923.236416                 2070.871802    105.622055
# 8        5154.400250                 2134.831988    111.783567
# 9        5343.463567                 2246.217035    117.880761
# 10       5485.583397                 2378.917896    116.395110
# 11       5669.401393                 2417.523137    118.518656
# 12       5940.649484                 2442.009444    123.482961
# 13       6069.902203                 3026.151820    125.137736
# 14       6347.589291                 3156.358528    137.897434
# 15       6367.797098                 3087.223548    133.762122
# 16       6437.920949                 3068.717667    123.401287
# 17       6642.205911                 3185.128774    120.233435
# 18       7308.342743                 2864.661794    116.550547
# 19       7628.195070                 2909.827021    163.610394
# 20       7081.127077                 3330.558609    134.726639
# 21       7299.585807                 3380.823704    138.137561
# 22       4132.923995                 3722.771710    243.352651
# 23       4201.025101                 3676.046204    247.419624
# 24       4295.477744                 3374.020771    239.016625
# 25       4360.484647                 3599.758655    231.085527
# 26       4250.259866                 3389.784456    232.891850
# 27       4223.763969                 3365.040707    248.154636
# 28       4229.098020                 3463.634662    254.600227
# 29       4491.838566                 3502.446383    268.624941
# 30       4382.900709                 3474.570994    268.005392
# 31       4549.066789                 3555.009564    267.732030
# 32       4506.725398                 3652.311275    282.710929
# 33       4473.358122                 3647.680198    299.971076
# 34       4574.446090                 3486.731921    294.774661
# 35       4450.356376                 3418.737391    247.055297
#
#     Passenger_Car_EFF  Passenger_Car_Age  \
# 0           27.600000              10.15
# 1           28.000000              10.15
# 2           28.400000              10.15
# 3           27.900000              10.15
# 4           28.400000              10.15
# 5           28.300000              10.15
# 6           28.600000              10.15
# 7           28.500000              10.15
# 8           28.700000              10.15
# 9           28.800000              10.15
# 10          28.300000               9.45
# 11          28.500000               9.45
# 12          28.800000               9.45
# 13          29.000000               9.45
# 14          29.500000               9.45
# 15          29.491622               9.45
# 16          30.321077               9.45
# 17          30.087723               9.80
# 18          31.242083               9.90
# 19          31.469337              10.00
# 20          32.900238              10.10
# 21          33.937919              10.20
# 22          33.126479              10.30
# 23          35.270757              10.40
# 24          36.399878              10.50
# 25          36.537293              10.80
# 26          36.705156              10.85
# 27          36.705156              10.85
# 28          36.705156              10.85
# 29          29.491622              10.85
# 30          29.491622              10.85
# 31          29.491622              10.85
# 32          29.491622              10.15
# 33          29.491622              10.15
# 34          29.491622              10.15
# 35          29.491622              10.15
#
#     Demand_petroleum_transportation)mil_lit  Average_MC/15000_miles(dollars)  \
# 0                             324557.386472                         7788.500
# 1                             339177.522046                         7788.500
# 2                             389881.923382                         3087.875
# 3                             396853.724860                         3176.000
# 4                             407271.871414                         3484.000
# 5                             430043.766812                         4954.000
# 6                             424806.490322                         5601.000
# 7                             434878.252752                         5824.000
# 8                             441299.583402                         5804.000
# 9                             449392.241588                         5916.000
# 10                            455205.835698                         6185.000
# 11                            464439.859954                         6389.000
# 12                            470636.961724                         6723.000
# 13                            484447.583157                         6908.000
# 14                            498846.775589                         7050.000
# 15                            499126.426686                         7363.000
# 16                            506261.860169                         7654.000
# 17                            519585.253652                         7534.000
# 18                            524688.496273                         7754.000
# 19                            534431.817430                         8431.000
# 20                            529914.352174                         8410.000
# 21                            529135.132685                         7834.000
# 22                            529568.751629                         7823.000
# 23                            514906.950025                         8121.000
# 24                            517644.722757                         8096.000
# 25                            521273.740460                         8487.000
# 26                            511580.806922                         8776.000
# 27                            509446.531070                         8946.000
# 28                            511564.541006                         9122.000
# 29                            529997.343547                         8876.000
# 30                            535005.960060                         8698.000
# 31                            548303.470215                         8558.000
# 32                            547276.174959                         8468.000
# 33                            549774.962911                         8849.000
# 34                            553756.463038                         9282.000
# 35                            483422.909983                         9561.000
#
#     CO2_emission_million_metric_tons  CO_emission_million_shots_tons  \
# 0                          1822.6075                      100.812773
# 1                          1822.6075                      204.042000
# 2                          1340.3690                      188.398000
# 3                          1397.3680                      185.408000
# 4                          1423.0270                      176.845000
# 5                          1586.7380                      154.188000
# 6                          1566.9800                      147.128000
# 7                          1590.5970                      140.895000
# 8                          1603.8740                      135.902000
# 9                          1644.0500                      133.558000
# 10                         1678.5520                      126.778000
# 11                         1728.6100                      128.858139
# 12                         1747.7120                      117.910141
# 13                         1785.2530                      115.380100
# 14                         1831.8090                      114.541264
# 15                         1887.6650                      114.466633
# 16                         1859.3940                      106.262327
# 17                         1898.7310                      102.032848
# 18                         1916.5840                       99.592698
# 19                         1971.5990                       97.147153
# 20                         1992.3660                       88.545890
# 21                         2023.2930                       85.837099
# 22                         2026.3250                       83.128309
# 23                         1895.5310                       79.655089
# 24                         1831.5530                       72.752525
# 25                         1847.1570                       73.771049
# 26                         1812.8790                       73.761574
# 27                         1775.7910                       71.758191
# 28                         1795.4770                       69.754808
# 29                         1813.6620                       65.537023
# 30                         1836.9940                       63.515540
# 31                         1869.3250                       58.904365
# 32                         1886.2920                       66.604683
# 33                         1917.7600                       62.282826
# 34                         1923.8530                       52.118160
# 35                         1632.0510                      100.812773
#
#     NOx_emission_million_shots_tons  SOx_emission_million_shots_tons  \
# 0                         22.073472                        14.920004
# 1                         26.882000                        31.218000
# 2                         26.378000                        28.044000
# 3                         27.080000                        25.926000
# 4                         25.757000                        23.307000
# 5                         25.527000                        23.077000
# 6                         25.180000                        22.374851
# 7                         25.261000                        22.082000
# 8                         25.356000                        21.773000
# 9                         25.350000                        21.346000
# 10                        24.955000                        18.619000
# 11                        24.787361                        18.385268
# 12                        24.704957                        18.839865
# 13                        24.347760                        18.944408
# 14                        22.844743                        17.545486
# 15                        22.598434                        16.346998
# 16                        21.548511                        15.931656
# 17                        23.958761                        15.032065
# 18                        22.650576                        14.807944
# 19                        21.331140                        14.571443
# 20                        20.354764                        14.545748
# 21                        19.227000                        13.122556
# 22                        18.099236                        11.699364
# 23                        16.909359                        10.323658
# 24                        15.771705                         9.089238
# 25                        14.846454                         7.732208
# 26                        14.518914                         6.478839
# 27                        13.878782                         5.079293
# 28                        13.238651                         4.873418
# 29                        12.589335                         4.674456
# 30                        11.681853                         3.945029
# 31                        10.303740                         3.204068
# 32                         9.838189                         2.539499
# 33                         9.211322                         2.438492
# 34                         8.568517                         1.984031
# 35                        22.073472                        14.920004
#
#     Volatile_compound_million_shots_tons  overall_emission
# 0                              18.212114       2000.164176
# 1                              29.046433       2132.430500
# 2                              29.046433       1665.151612
# 3                              29.046433       1673.902000
# 4                              27.403000       1717.662000
# 5                              24.108000       1841.391000
# 6                              23.577000       1812.584851
# 7                              23.066000       1828.999000
# 8                              22.730000       1836.999000
# 9                              22.570000       1875.482000
# 10                             22.042000       1896.766000
# 11                             20.871235       1944.369001
# 12                             19.530183       1951.605775
# 13                             18.781439       1985.599375
# 14                             18.269942       2028.393820
# 15                             17.512342       2082.336284
# 16                             17.111263       2043.955351
# 17                             20.289449       2081.620001
# 18                             19.910970       2095.210674
# 19                             19.513839       2145.911621
# 20                             17.753006       2154.866930
# 21                             17.901738       2180.782527
# 22                             18.050470       2178.803124
# 23                             17.758856       2041.757895
# 24                             17.593197       1967.958906
# 25                             17.835014       1982.164750
# 26                             18.154287       1946.515142
# 27                             17.872104       1904.348893
# 28                             17.589921       1920.150316
# 29                             16.882678       1931.528769
# 30                             16.329780       1949.992185
# 31                             15.458595       1974.026137
# 32                             17.184851       1999.494202
# 33                             16.434534       2024.522562
# 34                             13.678406       2015.284264
# 35                             18.212114       1809.607676

# %%
# Creating a CSV file
data2.to_csv("co2_cleaned", index=False, encoding = "utf-8")

# %% [markdown]
# **Feature Scaling**
#
# **As data is not normally distributed we use Normalization technique.**

# %%
import pandas as pd
df = pd.read_csv("/content/co2_cleaned")
df.head()
# Out:
#      year  Jet Fuel_avi_BTU  Gasoline_avi_BTU  LDV_SWB_road_BTU  \
# 0  1967.5        954.004500         35.098400       5980.980778
# 1  1970.0       1060.695000         54.164884       8164.903979
# 2  1975.0       1020.330000         49.522400       8931.556064
# 3  1980.0       1150.096472         54.164884       8442.341323
# 4  1985.0       1365.525967         50.604200       8624.481448
#
#    LDV_LWB_road_BTU  Combination_Truck_road_BTU  Bus_Road_BTU  \
# 0       4549.066789                  800.864188    105.250250
# 1       1728.549029                  883.853950     98.660622
# 2       2295.138398                 1103.921827    126.666330
# 3       2862.349250                 1568.168922    122.489519
# 4       4002.009473                 1684.638041    100.279579
#
#    Passenger_Car_EFF  Passenger_Car_Age  \
# 0               27.6              10.15
# 1               28.0              10.15
# 2               28.4              10.15
# 3               27.9              10.15
# 4               28.4              10.15
#
#    Demand_petroleum_transportation)mil_lit  Average_MC/15000_miles(dollars)  \
# 0                            324557.386472                         7788.500
# 1                            339177.522046                         7788.500
# 2                            389881.923382                         3087.875
# 3                            396853.724860                         3176.000
# 4                            407271.871414                         3484.000
#
#    CO2_emission_million_metric_tons  CO_emission_million_shots_tons  \
# 0                         1822.6075                      100.812773
# 1                         1822.6075                      204.042000
# 2                         1340.3690                      188.398000
# 3                         1397.3680                      185.408000
# 4                         1423.0270                      176.845000
#
#    NOx_emission_million_shots_tons  SOx_emission_million_shots_tons  \
# 0                        22.073472                        14.920004
# 1                        26.882000                        31.218000
# 2                        26.378000                        28.044000
# 3                        27.080000                        25.926000
# 4                        25.757000                        23.307000
#
#    Volatile_compound_million_shots_tons  overall_emission
# 0                             18.212114       2000.164176
# 1                             29.046433       2132.430500
# 2                             29.046433       1665.151612
# 3                             29.046433       1673.902000
# 4                             27.403000       1717.662000

# %%
df.columns
# Out:
# Index(['year', 'Jet Fuel_avi_BTU', 'Gasoline_avi_BTU', 'LDV_SWB_road_BTU',
#        'LDV_LWB_road_BTU', 'Combination_Truck_road_BTU', 'Bus_Road_BTU',
#        'Passenger_Car_EFF', 'Passenger_Car_Age',
#        'Demand_petroleum_transportation)mil_lit',
#        'Average_MC/15000_miles(dollars)', 'CO2_emission_million_metric_tons',
#        'CO_emission_million_shots_tons', 'NOx_emission_million_shots_tons',
#        'SOx_emission_million_shots_tons',
#        'Volatile_compound_million_shots_tons', 'overall_emission'],
#       dtype='object')

# %%
df.shape
# Out:
# (36, 17)

# %%
columns2 = ['year', 'Jet Fuel_avi_BTU', 'Gasoline_avi_BTU', 'LDV_SWB_road_BTU',
       'LDV_LWB_road_BTU', 'Combination_Truck_road_BTU', 'Bus_Road_BTU',
       'Passenger_Car_EFF', 'Passenger_Car_Age',
       'Demand_petroleum_transportation)mil_lit',
       'Average_MC/15000_miles(dollars)', 'CO2_emission_million_metric_tons',
       'CO_emission_million_shots_tons', 'NOx_emission_million_shots_tons',
       'SOx_emission_million_shots_tons',
       'Volatile_compound_million_shots_tons']

# %%
from sklearn.model_selection import train_test_split

X = df.drop("overall_emission", axis=1)
y = df['overall_emission']

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.20,random_state =3)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_train = pd.DataFrame(X_train, columns=columns2)
X_test = scaler.fit_transform(X_test)
X_test = pd.DataFrame(X_test, columns=columns2 )

# %%
X_test
# Out:
#        year  Jet Fuel_avi_BTU  Gasoline_avi_BTU  LDV_SWB_road_BTU  \
# 0  0.000000          0.000000          1.000000          0.000000
# 1  0.962963          0.188269          0.044338          0.820023
# 2  0.666667          0.607596          0.307273          0.189411
# 3  0.814815          0.761158          0.313200          1.000000
# 4  0.629630          0.573336          0.327409          0.190184
# 5  0.851852          0.621426          0.193902          0.690128
# 6  0.555556          1.000000          0.588911          0.075584
# 7  1.000000          0.032463          0.000000          0.834725
#
#    LDV_LWB_road_BTU  Combination_Truck_road_BTU  Bus_Road_BTU  \
# 0          0.000000                    0.000000      0.000000
# 1          0.075083                    0.836621      0.896786
# 2          1.000000                    0.578973      0.110032
# 3          0.039595                    1.000000      0.967527
# 4          0.798527                    0.736208      0.134937
# 5          0.060192                    0.977074      0.995030
# 6          0.715532                    0.688172      0.226425
# 7          0.067070                    0.824481      1.000000
#
#    Passenger_Car_EFF  Passenger_Car_Age  \
# 0           0.000000           0.500000
# 1           1.000000           1.000000
# 2           0.342207           0.321429
# 3           0.569102           0.607143
# 4           0.203214           0.250000
# 5           0.827288           0.678571
# 6           0.131439           0.000000
# 7           1.000000           1.000000
#
#    Demand_petroleum_transportation)mil_lit  Average_MC/15000_miles(dollars)  \
# 0                                 0.000000                         0.000000
# 1                                 0.852916                         0.968876
# 2                                 0.960095                         0.781765
# 3                                 1.000000                         0.794398
# 4                                 0.918367                         0.741487
# 5                                 0.880113                         0.848956
# 6                                 0.751078                         0.710179
# 7                                 0.835464                         1.000000
#
#    CO2_emission_million_metric_tons  CO_emission_million_shots_tons  \
# 0                          0.000000                        1.000000
# 1                          0.646201                        0.019064
# 2                          0.818098                        0.264872
# 3                          1.000000                        0.108197
# 4                          0.788506                        0.288092
# 5                          0.783202                        0.075146
# 6                          0.770163                        0.406411
# 7                          0.584726                        0.000000
#
#    NOx_emission_million_shots_tons  SOx_emission_million_shots_tons  \
# 0                         1.000000                         1.000000
# 1                         0.053891                         0.076781
# 2                         0.738477                         0.533729
# 3                         0.355310                         0.363187
# 4                         0.848610                         0.546024
# 5                         0.255137                         0.287714
# 6                         0.734088                         0.618164
# 7                         0.000000                         0.000000
#
#    Volatile_compound_million_shots_tons
# 0                              1.000000
# 1                              0.064904
# 2                              0.242515
# 3                              0.054408
# 4                              0.280781
# 5                              0.024924
# 6                              0.000000
# 7                              0.036374

# %%
X_train.head()
# Out:
#        year  Jet Fuel_avi_BTU  Gasoline_avi_BTU  LDV_SWB_road_BTU  \
# 0  0.580952          0.840060          0.476903          0.502322
# 1  0.961905          0.644077          0.179037          0.958509
# 2  0.428571          0.693087          0.633468          0.453817
# 3  1.000000          0.022387          0.000000          0.580056
# 4  0.980952          0.689310          0.059615          1.000000
#
#    LDV_LWB_road_BTU  Combination_Truck_road_BTU  Bus_Road_BTU  \
# 0          0.735867                    0.780406      0.131524
# 1          0.465250                    0.998376      1.000000
# 2          0.433070                    0.399692      0.044740
# 3          0.461351                    0.918086      0.737143
# 4          0.482384                    0.941931      0.974187
#
#    Passenger_Car_EFF  Passenger_Car_Age  \
# 0           0.153759                0.0
# 1           0.207753                0.5
# 2           0.076880                0.5
# 3           0.207753                0.5
# 4           0.207753                0.5
#
#    Demand_petroleum_transportation)mil_lit  Average_MC/15000_miles(dollars)  \
# 0                                 0.697604                         0.590152
# 1                                 0.982629                         0.890007
# 2                                 0.460239                         0.288288
# 3                                 0.693133                         1.000000
# 4                                 1.000000                         0.956899
#
#    CO2_emission_million_metric_tons  CO_emission_million_shots_tons  \
# 0                          0.651440                        0.416406
# 1                          0.845469                        0.066906
# 2                          0.360756                        0.671849
# 3                          0.427108                        0.320520
# 4                          0.854391                        0.000000
#
#    NOx_emission_million_shots_tons  SOx_emission_million_shots_tons  \
# 0                         0.852403                         0.580160
# 1                         0.034725                         0.015546
# 2                         0.916106                         0.721523
# 3                         0.729545                         0.442498
# 4                         0.000000                         0.000000
#
#    Volatile_compound_million_shots_tons
# 0                              0.332055
# 1                              0.179342
# 2                              0.678655
# 3                              0.295009
# 4                              0.000000

# %%
import pickle
pickle.dump(scaler, open('scaling1.pkl', 'wb'))

# %%
# Creating a CSV file
df1 = df.to_csv("emission_cleaned", index=False, encoding = "utf-8")

# %% [markdown]
# **Model Building**

# %% [markdown]
# ## **MANUAL MODEL BUILDING**

# %%
df.columns
# Out:
# Index(['year', 'Jet Fuel_avi_BTU', 'Gasoline_avi_BTU', 'LDV_SWB_road_BTU',
#        'LDV_LWB_road_BTU', 'Combination_Truck_road_BTU', 'Bus_Road_BTU',
#        'Passenger_Car_EFF', 'Passenger_Car_Age',
#        'Demand_petroleum_transportation)mil_lit',
#        'Average_MC/15000_miles(dollars)', 'CO2_emission_million_metric_tons',
#        'CO_emission_million_shots_tons', 'NOx_emission_million_shots_tons',
#        'SOx_emission_million_shots_tons',
#        'Volatile_compound_million_shots_tons', 'overall_emission'],
#       dtype='object')

# %%
df.rename(columns = {'Demand_petroleum_transportation)mil_lit':'Demand_Petro',"Jet Fuel_avi_BTU":"Jet_Fuel_avi_BTU",'Average_MC/15000_miles(dollars)':'Avg_MC'}, inplace=True)

# %%
# importing module
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
import numpy as np

# creating an object of LinearRegression class
LR = LinearRegression()
# fitting the training data
LR.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_prediction =  LR.predict(X_test)
y_prediction
# Out:
# array([1663.35476542, 1881.59474288, 2075.3145259 , 2140.1751617 ,
#        2047.5516513 , 1987.7614451 , 2048.63965395, 1831.67036456])

# %%
print('Train Score: ', LR.score(X_train, y_train))  
print('Test Score: ', LR.score(X_test, y_test))
# Out:
# Train Score:  0.9990388493031016
# Test Score:  0.8676241444290791

# %%
# predicting the accuracy score
score=r2_score(y_test,y_prediction)
print('r2 score is ',score)
print('mean_sqrd_error is==',mean_squared_error(y_test,y_prediction))
print('root_mean_squared error of is==',np.sqrt(mean_squared_error(y_test,y_prediction)))
# Out:
# r2 score is  0.8676241444290791
# mean_sqrd_error is== 2443.2263131776735
# root_mean_squared error of is== 49.42900275321841

# %% [markdown]
# **Bayesian Ridge Regression**

# %% [markdown]
# **Bayesian Regression can be very useful when we have insufficient data in the dataset or the data is poorly distributed. The output of a Bayesian Regression model is obtained from a probability distribution, as compared to regular regression techniques where the output is just obtained from a single value of each attribute.**

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.linear_model import BayesianRidge

# %%
# Creating and training model
model_BR = BayesianRidge()
model_BR.fit(X_train, y_train)
# Out:
# BayesianRidge()

# %%
# Model making a prediction on test data
prediction = model_BR.predict(X_test)

# %%
# Evaluation of r2 score of the model against the test set
print(f"r2 Score Of Test Set : {r2_score(y_test, prediction)}")
# Out:
# r2 Score Of Test Set : 0.8770292689766945

# %%
# Saving model to disk
pickle.dump(model_BR, open('model1.pkl','wb'))

# %%
# Loading model to compare the results
model = pickle.load(open('model1.pkl','rb'))

# %%
print(model.predict([[0,1,2,3,4,5,6,8,9,10,11,12,13,14,15,16]]))
# Out:
# [12459.54497348]
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but BayesianRidge was fitted with feature names
#   "X does not have valid feature names, but"
